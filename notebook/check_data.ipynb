# %%
import pandas as pd

# %%
import pandas as pd

# Path to your CSV file
csv_path = "/home/ubuntu/project/Tumor_Detection/ratio_out.csv"

# Load CSV into a DataFrame
df = pd.read_csv(csv_path)

# Select only class ratio columns (skip 'patch_name')
class_columns = ["background_ratio", "stroma_ratio", "benign_ratio", "tumor_ratio"]

# Compute statistics
stats = df[class_columns].agg(['min', 'mean', 'max'])

# Rename 'mean' to 'avg' for clarity
stats = stats.rename(index={'mean': 'avg'})

# Display results
print(stats.T.round(6))  # Transpose for better readability
# Out:
#                   min       avg       max
# background_ratio  0.0  0.367770  1.000000
# stroma_ratio      0.0  0.535078  1.000000
# benign_ratio      0.0  0.030461  0.572632
# tumor_ratio       0.0  0.066690  0.702011

# %%
import pandas as pd

# Path to your CSV file
csv_path = "/home/ubuntu/project/Tumor_Detection/ratio_out.csv"

# Load the CSV
df = pd.read_csv(csv_path)

# Class columns (excluding patch_name)
class_columns = ["background_ratio", "stroma_ratio", "benign_ratio", "tumor_ratio"]

# Define percentiles to compute
percentiles = [0.0, 0.25, 0.5, 0.7, 0.9, 1.0]

# Compute percentiles
stats = df[class_columns].quantile(percentiles)

# Label the index nicely
stats.index = ['0%', '25%', '50%', '70%', '90%', '100%']

# Transpose for better readability (each class as row)
print(stats.round(6))
# Out:
#       background_ratio  stroma_ratio  benign_ratio  tumor_ratio
# 0%            0.000000      0.000000      0.000000     0.000000
# 25%           0.120804      0.338638      0.000000     0.000000
# 50%           0.341370      0.534103      0.003662     0.000000
# 70%           0.545133      0.691189      0.024548     0.053961
# 90%           0.747162      0.888785      0.101679     0.255753
# 100%          1.000000      1.000000      0.572632     0.702011

# %%
csv_path = "/home/ubuntu/project/Tumor_Detection/ratio_out.csv"
df = pd.read_csv(csv_path)
df_sorted = df.sort_values(by="stroma_ratio", ascending=False)

df_sorted[400:500]
# Out:
#                                          patch_name  background_ratio  \
# 287  4fce030094773bdf132fd81c5febce40_1280_5632.png          0.000000
# 941   e2f04baa0bee5232b73ca726d29a870b_3584_512.png          0.106277
# 948   e2f04baa0bee5232b73ca726d29a870b_4608_512.png          0.000000
# 107   32291426a698e316ff990f4b93e27e98_2560_256.png          0.187927
# 182   47791bc4ed9a7eb5329f4af7c4bbb84d_4352_512.png          0.351715
# ..                                              ...               ...
# 288  4fce030094773bdf132fd81c5febce40_1280_5888.png          0.037827
# 239  4a7a70d00251af024d70dab5a7e8d228_3584_1280.png          0.428421
# 327  5a112beb1fb4921df86062b489f41928_1024_1536.png          0.329880
# 47    173b49fe81aff971168dc5d7ef4124d8_1280_256.png          0.051514
# 554   80b59404657a6290a06e8902430be7fc_3840_768.png          0.450317
#
#      stroma_ratio  benign_ratio  tumor_ratio
# 287      0.601288      0.000000     0.398712
# ...

# %%
import numpy as np
import torch 
numDataPoints = 1000
data_dim = 5
bs = 100

# Create dummy data with class imbalance 9 to 1
data = torch.FloatTensor(numDataPoints, data_dim)
target = np.hstack((np.zeros(int(numDataPoints * 0.9), dtype=np.int32),
                    np.ones(int(numDataPoints * 0.1), dtype=np.int32)))

print ('target train 0/1: {}/{}'.format(
    len(np.where(target == 0)[0]), len(np.where(target == 1)[0])))

class_sample_count = np.array(
    [len(np.where(target == t)[0]) for t in np.unique(target)])
weight = 1. / class_sample_count
samples_weight = np.array([weight[t] for t in target])

samples_weight = torch.from_numpy(samples_weight)
samples_weigth = samples_weight.double()


len(samples_weight), samples_weight
# Out:
# target train 0/1: 900/100
# (1000,
#  tensor([0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011,
#          0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011,
#          0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011,
#          0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011,
#          0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011,
#          0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011,
#          0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011,
#          0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011,
#          0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011,
#          0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011,
#          0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011,
# ...
